# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(10, 10), dpi=360)

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#        algo topology  time(microseconds)     n  Deathprob             Status
# 0    gossip     line             1291125    10        0.0                 ok
# 1    gossip  grid_2d              639011    16        0.0                 ok
# 2    gossip  grid_3d              433744    27        0.0                 ok
# 3    gossip     line              571397   100        0.0                 ok
# 4    gossip  grid_2d              764856   100        0.0                 ok
# ..      ...      ...                 ...   ...        ...                ...
# 127  gossip  grid_3d             1718914    27        0.1  dead_node_success
# 128  gossip  grid_3d             1533806   125        0.1  dead_node_success
# 129  gossip  grid_3d             2211121  1000        0.1  dead_node_success
# 130  gossip  grid_3d             4897412  2197        0.1  dead_node_success
# 131  gossip  grid_3d             4083959  3375        0.1  dead_node_success
#
# [132 rows x 6 columns]

# %%
gossip_full_success = data.loc[(data['topology'] == 'full') & (data['Deathprob'] == 0.0) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_full_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob Status
# 0  gossip     full                 956    10        0.0     ok
# 1  gossip     full                4679   100        0.0     ok
# 2  gossip     full                9974   200        0.0     ok
# 3  gossip     full               16450   600        0.0     ok
# 4  gossip     full               41909  1000        0.0     ok
# 7  gossip     full              129243  1500        0.0     ok
# 5  gossip     full              119145  2000        0.0     ok
# 8  gossip     full              222740  2500        0.0     ok
# 6  gossip     full              380714  3000        0.0     ok

# %%
gossip_line_success = data.loc[(data['topology'] == 'line') & (data['Deathprob'] == 0.0) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_line_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob Status
# 0  gossip     line             1291125    10        0.0     ok
# 1  gossip     line              571397   100        0.0     ok
# 3  gossip     line              939468   200        0.0     ok
# 4  gossip     line              828824   600        0.0     ok
# 2  gossip     line             2178197  1000        0.0     ok
# 7  gossip     line             2447282  1500        0.0     ok
# 5  gossip     line             2447184  2000        0.0     ok
# 8  gossip     line             2508086  2500        0.0     ok
# 6  gossip     line             3009437  3000        0.0     ok

# %%
gossip_grid2d_success = data.loc[(data['topology'] == 'grid_2d') & (data['Deathprob'] == 0.0) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid2d_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob Status
# 0  gossip  grid_2d              639011    16        0.0     ok
# 1  gossip  grid_2d              764856   100        0.0     ok
# 3  gossip  grid_2d             1165722   225        0.0     ok
# 4  gossip  grid_2d             1532038   625        0.0     ok
# 2  gossip  grid_2d             1262598  1024        0.0     ok
# 7  gossip  grid_2d             1164348  1521        0.0     ok
# 5  gossip  grid_2d             2011492  2025        0.0     ok
# 8  gossip  grid_2d             1263281  2500        0.0     ok
# 6  gossip  grid_2d             1550819  3025        0.0     ok

# %%
gossip_grid3d_success = data.loc[(data['topology'] == 'grid_3d') & (data['Deathprob'] == 0.0) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid3d_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob Status
# 0  gossip  grid_3d              433744    27        0.0     ok
# 1  gossip  grid_3d             1397071   125        0.0     ok
# 3  gossip  grid_3d             1327607   216        0.0     ok
# 4  gossip  grid_3d             1716442   729        0.0     ok
# 2  gossip  grid_3d             1946547  1000        0.0     ok
# 7  gossip  grid_3d             1605595  1728        0.0     ok
# 5  gossip  grid_3d             1463077  2197        0.0     ok
# 8  gossip  grid_3d             1722835  2744        0.0     ok
# 6  gossip  grid_3d             1729695  3375        0.0     ok

# %%
# plot lines
plt.plot(gossip_full_success['n'], gossip_full_success['time(microseconds)']/1000, label = gossip_full_success['topology'][0], marker='o')
plt.plot(gossip_line_success['n'], gossip_line_success['time(microseconds)']/1000, label = gossip_line_success['topology'][0], marker='v')
plt.plot(gossip_grid2d_success['n'], gossip_grid2d_success['time(microseconds)']/1000, label = gossip_grid2d_success['topology'][0], marker='^')
plt.plot(gossip_grid3d_success['n'], gossip_grid3d_success['time(microseconds)']/1000, label = gossip_grid3d_success['topology'][0], marker='*')
plt.legend()
plt.xlabel("Number of Actors")
plt.ylabel("Time in milliseconds")
plt.savefig('gossip_runtime')
plt.rcParams["figure.figsize"] = (10,8)
plt.show()

# %%
gossip_full_success = data.loc[(data['topology'] == 'full') & (data['Deathprob'] == 0.0) \
                              & (data['algo'] == "'push-sum'")].reset_index(drop=True).sort_values(by=['n'])
gossip_full_success
# Out:
#          algo topology  time(microseconds)     n  Deathprob Status
# 0  'push-sum'     full                2121    10        0.0     ok
# 1  'push-sum'     full               37029   100        0.0     ok
# 2  'push-sum'     full               97147   200        0.0     ok
# 3  'push-sum'     full              247047   600        0.0     ok
# 4  'push-sum'     full              545871  1000        0.0     ok
# 5  'push-sum'     full              615735  1500        0.0     ok
# 6  'push-sum'     full              614512  2000        0.0     ok
# 7  'push-sum'     full              698872  2500        0.0     ok
# 8  'push-sum'     full              829170  3000        0.0     ok

# %%
gossip_line_success = data.loc[(data['topology'] == 'line') & (data['Deathprob'] == 0.0) \
                              & (data['algo'] == "'push-sum'")].reset_index(drop=True).sort_values(by=['n'])
gossip_line_success
# Out:
#          algo topology  time(microseconds)     n  Deathprob Status
# 0  'push-sum'     line                8794    10        0.0     ok
# 1  'push-sum'     line             1929401   100        0.0     ok
# 2  'push-sum'     line             6106625   200        0.0     ok
# 3  'push-sum'     line             2270870   600        0.0     ok
# 4  'push-sum'     line             1825568  1000        0.0     ok
# 5  'push-sum'     line             5015654  1500        0.0     ok
# 6  'push-sum'     line             4962365  2000        0.0     ok
# 7  'push-sum'     line             7002931  2500        0.0     ok
# 8  'push-sum'     line            11986031  3000        0.0     ok

# %%
gossip_grid2d_success = data.loc[(data['topology'] == 'grid_2d') & (data['Deathprob'] == 0.0) \
                              & (data['algo'] == "'push-sum'")].reset_index(drop=True).sort_values(by=['n'])
gossip_grid2d_success
# Out:
#          algo topology  time(microseconds)     n  Deathprob Status
# 0  'push-sum'  grid_2d                5952    16        0.0     ok
# 1  'push-sum'  grid_2d              113669   100        0.0     ok
# 2  'push-sum'  grid_2d              377196   225        0.0     ok
# 3  'push-sum'  grid_2d             2086109   625        0.0     ok
# 4  'push-sum'  grid_2d             6866633  1024        0.0     ok
# 5  'push-sum'  grid_2d            15513177  1521        0.0     ok
# 6  'push-sum'  grid_2d            24990663  2025        0.0     ok
# 7  'push-sum'  grid_2d            36115413  2500        0.0     ok
# 8  'push-sum'  grid_2d            45368086  3025        0.0     ok

# %%
gossip_grid3d_success = data.loc[(data['topology'] == 'grid_3d') & (data['Deathprob'] == 0.0) \
                              & (data['algo'] == "'push-sum'")].reset_index(drop=True).sort_values(by=['n'])
gossip_grid3d_success
# Out:
#          algo topology  time(microseconds)     n  Deathprob Status
# 0  'push-sum'  grid_3d                6429    27        0.0     ok
# 1  'push-sum'  grid_3d               85366   125        0.0     ok
# 2  'push-sum'  grid_3d               79410   216        0.0     ok
# 3  'push-sum'  grid_3d              563525   729        0.0     ok
# 4  'push-sum'  grid_3d              707085  1000        0.0     ok
# 5  'push-sum'  grid_3d              840926  1728        0.0     ok
# 6  'push-sum'  grid_3d              901887  2197        0.0     ok
# 7  'push-sum'  grid_3d              764131  2744        0.0     ok
# 8  'push-sum'  grid_3d             1229423  3375        0.0     ok

# %%
# plot lines
plt.plot(gossip_full_success['n'], gossip_full_success['time(microseconds)']/1000, label = gossip_full_success['topology'][0], marker='o')
plt.plot(gossip_line_success['n'], gossip_line_success['time(microseconds)']/1000, label = gossip_line_success['topology'][0], marker='v')
plt.plot(gossip_grid2d_success['n'], gossip_grid2d_success['time(microseconds)']/1000, label = gossip_grid2d_success['topology'][0], marker='^')
plt.plot(gossip_grid3d_success['n'], gossip_grid3d_success['time(microseconds)']/1000, label = gossip_grid3d_success['topology'][0], marker='*')
plt.legend()
plt.xlabel("Number of Actors")
plt.ylabel("Time in milliseconds")
plt.rcParams["figure.figsize"] = (10,8)
plt.savefig('push_sum_runtime')
plt.show()

# %%
gossip_full_success = data.loc[(data['topology'] == 'full') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_full_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip     full              207698    10       0.25  dead_node_success
# 1  gossip     full                4665   100       0.25  dead_node_success
# 2  gossip     full              119995  1000       0.25  dead_node_success
# 3  gossip     full              150497  2000       0.25  dead_node_success
# 4  gossip     full              355470  3000       0.25  dead_node_success

# %%
gossip_full_dead = data.loc[(data['topology'] == 'full') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'dead_node_success')].reset_index(drop=True).sort_values(by=['n'])
gossip_full_dead
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip     full              207698    10       0.25  dead_node_success
# 1  gossip     full                4665   100       0.25  dead_node_success
# 2  gossip     full              119995  1000       0.25  dead_node_success
# 3  gossip     full              150497  2000       0.25  dead_node_success
# 4  gossip     full              355470  3000       0.25  dead_node_success

# %%
gossip_full_fail = data.loc[(data['topology'] == 'full') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_full_fail
# Out:
# Empty DataFrame
# Columns: [algo, topology, time(microseconds), n, Deathprob, Status]
# Index: []

# %%
gossip_line_success = data.loc[(data['topology'] == 'line') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_line_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob  Status
# 0  gossip     line            11125873    10       0.25  failed
# 1  gossip     line            10822338   100       0.25  failed
# 2  gossip     line            10004920  1000       0.25  failed
# 3  gossip     line            11809724  2000       0.25  failed
# 4  gossip     line            11367529  3000       0.25  failed

# %%
gossip_line_dead = data.loc[(data['topology'] == 'line') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'dead_node_success')].reset_index(drop=True).sort_values(by=['n'])
gossip_line_dead
# Out:
# Empty DataFrame
# Columns: [algo, topology, time(microseconds), n, Deathprob, Status]
# Index: []

# %%
gossip_line_fail = data.loc[(data['topology'] == 'line') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_line_fail
# Out:
#      algo topology  time(microseconds)     n  Deathprob  Status
# 0  gossip     line            11125873    10       0.25  failed
# 1  gossip     line            10822338   100       0.25  failed
# 2  gossip     line            10004920  1000       0.25  failed
# 3  gossip     line            11809724  2000       0.25  failed
# 4  gossip     line            11367529  3000       0.25  failed

# %%
gossip_grid2d_success = data.loc[(data['topology'] == 'grid_2d') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid2d_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip  grid_2d              959595    16       0.25  dead_node_success
# 1  gossip  grid_2d            14577164   100       0.25             failed
# 2  gossip  grid_2d            16221580  1024       0.25             failed
# 3  gossip  grid_2d            16278627  2025       0.25             failed
# 4  gossip  grid_2d            18283897  3025       0.25             failed

# %%
gossip_grid2d_dead = data.loc[(data['topology'] == 'grid_2d') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'dead_node_success')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid2d_dead
# Out:
#      algo topology  time(microseconds)   n  Deathprob             Status
# 0  gossip  grid_2d              959595  16       0.25  dead_node_success

# %%
gossip_grid2d_fail = data.loc[(data['topology'] == 'grid_2d') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid2d_fail
# Out:
#      algo topology  time(microseconds)     n  Deathprob  Status
# 0  gossip  grid_2d            14577164   100       0.25  failed
# 1  gossip  grid_2d            16221580  1024       0.25  failed
# 2  gossip  grid_2d            16278627  2025       0.25  failed
# 3  gossip  grid_2d            18283897  3025       0.25  failed

# %%
gossip_grid3d_success = data.loc[(data['topology'] == 'grid_3d') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid3d_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip  grid_3d            10835897    27       0.25             failed
# 1  gossip  grid_3d             6012968   125       0.25  dead_node_success
# 2  gossip  grid_3d            14718102  1000       0.25             failed
# 3  gossip  grid_3d            17483307  2197       0.25             failed
# 4  gossip  grid_3d            20318660  3375       0.25             failed

# %%
gossip_grid3d_dead = data.loc[(data['topology'] == 'grid_3d') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'dead_node_success')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid3d_dead
# Out:
#      algo topology  time(microseconds)    n  Deathprob             Status
# 0  gossip  grid_3d             6012968  125       0.25  dead_node_success

# %%
gossip_grid3d_fail = data.loc[(data['topology'] == 'grid_3d') & (data['Deathprob'] == 0.25) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid3d_fail
# Out:
#      algo topology  time(microseconds)     n  Deathprob  Status
# 0  gossip  grid_3d            10835897    27       0.25  failed
# 1  gossip  grid_3d            14718102  1000       0.25  failed
# 2  gossip  grid_3d            17483307  2197       0.25  failed
# 3  gossip  grid_3d            20318660  3375       0.25  failed

# %%
# plot lines
plt.plot(gossip_full_success['n'], gossip_full_success['time(microseconds)']/1000, label = gossip_full_success['topology'][0])
plt.scatter(gossip_full_dead['n'], gossip_full_dead['time(microseconds)']/1000, label ='success with dead nodes', marker='o', c='g')
plt.scatter(gossip_full_fail['n'], gossip_full_fail['time(microseconds)']/1000, label ='fail with dead nodes', marker='v', c='r')

plt.plot(gossip_line_success['n'], gossip_line_success['time(microseconds)']/1000, label = gossip_line_success['topology'][0])
plt.scatter(gossip_line_dead['n'], gossip_line_dead['time(microseconds)']/1000, marker='o', c='g')
plt.scatter(gossip_line_fail['n'], gossip_line_fail['time(microseconds)']/1000, marker='v', c='r')

plt.plot(gossip_grid2d_success['n'], gossip_grid2d_success['time(microseconds)']/1000, label = gossip_grid2d_success['topology'][0])
plt.scatter(gossip_grid2d_dead['n'], gossip_grid2d_dead['time(microseconds)']/1000, marker='o', c='g')
plt.scatter(gossip_grid2d_fail['n'], gossip_grid2d_fail['time(microseconds)']/1000, marker='v', c='r')

plt.plot(gossip_grid3d_success['n'], gossip_grid3d_success['time(microseconds)']/1000, label = gossip_grid3d_success['topology'][0])
plt.scatter(gossip_grid3d_dead['n'], gossip_grid3d_dead['time(microseconds)']/1000, marker='o', c='g')
plt.scatter(gossip_grid3d_fail['n'], gossip_grid3d_fail['time(microseconds)']/1000, marker='v', c='r')
plt.legend()
plt.title("Probability of death = 0.25")
plt.xlabel("Number of Actors")
plt.ylabel("Time in milliseconds")
plt.rcParams["figure.figsize"] = (10,8)
plt.savefig('death25p')
plt.show()

# %%
gossip_full_success = data.loc[(data['topology'] == 'full') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_full_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip     full              681298    10        0.2                 ok
# 1  gossip     full                2474   100        0.2  dead_node_success
# 2  gossip     full               37850  1000        0.2  dead_node_success
# 3  gossip     full              240844  2000        0.2  dead_node_success
# 4  gossip     full              274013  3000        0.2  dead_node_success

# %%
gossip_full_dead = data.loc[(data['topology'] == 'full') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'dead_node_success')].reset_index(drop=True).sort_values(by=['n'])
gossip_full_dead
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip     full                2474   100        0.2  dead_node_success
# 1  gossip     full               37850  1000        0.2  dead_node_success
# 2  gossip     full              240844  2000        0.2  dead_node_success
# 3  gossip     full              274013  3000        0.2  dead_node_success

# %%
gossip_full_fail = data.loc[(data['topology'] == 'full') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_full_fail
# Out:
# Empty DataFrame
# Columns: [algo, topology, time(microseconds), n, Deathprob, Status]
# Index: []

# %%
gossip_line_success = data.loc[(data['topology'] == 'line') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_line_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob  Status
# 0  gossip     line            10203140    10        0.2  failed
# 1  gossip     line            11068031   100        0.2  failed
# 2  gossip     line            10456647  1000        0.2  failed
# 3  gossip     line            11119740  2000        0.2  failed
# 4  gossip     line            11212670  3000        0.2  failed

# %%
gossip_line_dead = data.loc[(data['topology'] == 'line') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'dead_node_success')].reset_index(drop=True).sort_values(by=['n'])
gossip_line_dead
# Out:
# Empty DataFrame
# Columns: [algo, topology, time(microseconds), n, Deathprob, Status]
# Index: []

# %%
gossip_line_fail = data.loc[(data['topology'] == 'line') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_line_fail
# Out:
#      algo topology  time(microseconds)     n  Deathprob  Status
# 0  gossip     line            10203140    10        0.2  failed
# 1  gossip     line            11068031   100        0.2  failed
# 2  gossip     line            10456647  1000        0.2  failed
# 3  gossip     line            11119740  2000        0.2  failed
# 4  gossip     line            11212670  3000        0.2  failed

# %%
gossip_grid2d_success = data.loc[(data['topology'] == 'grid_2d') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid2d_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip  grid_2d             1954552    16        0.2  dead_node_success
# 1  gossip  grid_2d             1413626   100        0.2  dead_node_success
# 2  gossip  grid_2d            15179861  1024        0.2  dead_node_success
# 3  gossip  grid_2d            15086796  2025        0.2             failed
# 4  gossip  grid_2d            15957127  3025        0.2             failed

# %%
gossip_grid2d_dead = data.loc[(data['topology'] == 'grid_2d') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'dead_node_success')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid2d_dead
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip  grid_2d             1954552    16        0.2  dead_node_success
# 1  gossip  grid_2d             1413626   100        0.2  dead_node_success
# 2  gossip  grid_2d            15179861  1024        0.2  dead_node_success

# %%
gossip_grid2d_fail = data.loc[(data['topology'] == 'grid_2d') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid2d_fail
# Out:
#      algo topology  time(microseconds)     n  Deathprob  Status
# 0  gossip  grid_2d            15086796  2025        0.2  failed
# 1  gossip  grid_2d            15957127  3025        0.2  failed

# %%
gossip_grid3d_success = data.loc[(data['topology'] == 'grid_3d') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid3d_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip  grid_3d             1414670    27        0.2  dead_node_success
# 1  gossip  grid_3d             4707834   125        0.2  dead_node_success
# 2  gossip  grid_3d             5407582  1000        0.2  dead_node_success
# 3  gossip  grid_3d            17797511  2197        0.2             failed
# 4  gossip  grid_3d            18921554  3375        0.2  dead_node_success

# %%
gossip_grid3d_dead = data.loc[(data['topology'] == 'grid_3d') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'dead_node_success')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid3d_dead
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip  grid_3d             1414670    27        0.2  dead_node_success
# 1  gossip  grid_3d             4707834   125        0.2  dead_node_success
# 2  gossip  grid_3d             5407582  1000        0.2  dead_node_success
# 3  gossip  grid_3d            18921554  3375        0.2  dead_node_success

# %%
gossip_grid3d_fail = data.loc[(data['topology'] == 'grid_3d') & (data['Deathprob'] == 0.2) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid3d_fail
# Out:
#      algo topology  time(microseconds)     n  Deathprob  Status
# 0  gossip  grid_3d            17797511  2197        0.2  failed

# %%
# plot lines
plt.plot(gossip_full_success['n'], gossip_full_success['time(microseconds)']/1000, label = gossip_full_success['topology'][0])
plt.scatter(gossip_full_dead['n'], gossip_full_dead['time(microseconds)']/1000, label ='success with dead nodes', marker='o', c='g')
plt.scatter(gossip_full_fail['n'], gossip_full_fail['time(microseconds)']/1000, label ='fail with dead nodes', marker='v', c='r')

plt.plot(gossip_line_success['n'], gossip_line_success['time(microseconds)']/1000, label = gossip_line_success['topology'][0])
plt.scatter(gossip_line_dead['n'], gossip_line_dead['time(microseconds)']/1000, marker='o', c='g')
plt.scatter(gossip_line_fail['n'], gossip_line_fail['time(microseconds)']/1000, marker='v', c='r')

plt.plot(gossip_grid2d_success['n'], gossip_grid2d_success['time(microseconds)']/1000, label = gossip_grid2d_success['topology'][0])
plt.scatter(gossip_grid2d_dead['n'], gossip_grid2d_dead['time(microseconds)']/1000, marker='o', c='g')
plt.scatter(gossip_grid2d_fail['n'], gossip_grid2d_fail['time(microseconds)']/1000, marker='v', c='r')

plt.plot(gossip_grid3d_success['n'], gossip_grid3d_success['time(microseconds)']/1000, label = gossip_grid3d_success['topology'][0])
plt.scatter(gossip_grid3d_dead['n'], gossip_grid3d_dead['time(microseconds)']/1000, marker='o', c='g')
plt.scatter(gossip_grid3d_fail['n'], gossip_grid3d_fail['time(microseconds)']/1000, marker='v', c='r')
plt.legend()
plt.title("Probability of death = 0.2")
plt.xlabel("Number of Actors")
plt.ylabel("Time in milliseconds")
plt.rcParams["figure.figsize"] = (10,8)
plt.savefig('death20p')
plt.show()

# %%
gossip_full_success = data.loc[(data['topology'] == 'full') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_full_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip     full                 479    10        0.1                 ok
# 1  gossip     full                3741   100        0.1  dead_node_success
# 2  gossip     full              113437  1000        0.1  dead_node_success
# 3  gossip     full              239354  2000        0.1  dead_node_success
# 4  gossip     full              224111  3000        0.1  dead_node_success

# %%
gossip_full_dead = data.loc[(data['topology'] == 'full') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip') & \
                            ((data['Status'] == 'dead_node_success') | (data['Status'] == 'ok'))].reset_index(drop=True).sort_values(by=['n'])
gossip_full_dead
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip     full                 479    10        0.1                 ok
# 1  gossip     full                3741   100        0.1  dead_node_success
# 2  gossip     full              113437  1000        0.1  dead_node_success
# 3  gossip     full              239354  2000        0.1  dead_node_success
# 4  gossip     full              224111  3000        0.1  dead_node_success

# %%
gossip_full_fail = data.loc[(data['topology'] == 'full') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_full_fail
# Out:
# Empty DataFrame
# Columns: [algo, topology, time(microseconds), n, Deathprob, Status]
# Index: []

# %%
gossip_line_success = data.loc[(data['topology'] == 'line') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_line_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob  Status
# 0  gossip     line             1190082    10        0.1      ok
# 1  gossip     line            10683497   100        0.1  failed
# 2  gossip     line            10130254  1000        0.1  failed
# 3  gossip     line            10001467  2000        0.1  failed
# 4  gossip     line            10713064  3000        0.1  failed

# %%
gossip_line_dead = data.loc[(data['topology'] == 'line') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip') & ((data['Status'] == 'dead_node_success') | (data['Status'] == 'ok'))].reset_index(drop=True).sort_values(by=['n'])
gossip_line_dead
# Out:
#      algo topology  time(microseconds)   n  Deathprob Status
# 0  gossip     line             1190082  10        0.1     ok

# %%
gossip_line_fail = data.loc[(data['topology'] == 'line') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_line_fail
# Out:
#      algo topology  time(microseconds)     n  Deathprob  Status
# 0  gossip     line            10683497   100        0.1  failed
# 1  gossip     line            10130254  1000        0.1  failed
# 2  gossip     line            10001467  2000        0.1  failed
# 3  gossip     line            10713064  3000        0.1  failed

# %%
gossip_grid2d_success = data.loc[(data['topology'] == 'grid_2d') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid2d_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip  grid_2d             1054894    16        0.1  dead_node_success
# 1  gossip  grid_2d             1258964   100        0.1  dead_node_success
# 2  gossip  grid_2d             2436008  1024        0.1  dead_node_success
# 3  gossip  grid_2d            13554823  2025        0.1             failed
# 4  gossip  grid_2d            14040428  3025        0.1             failed

# %%
gossip_grid2d_dead = data.loc[(data['topology'] == 'grid_2d') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'dead_node_success')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid2d_dead
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip  grid_2d             1054894    16        0.1  dead_node_success
# 1  gossip  grid_2d             1258964   100        0.1  dead_node_success
# 2  gossip  grid_2d             2436008  1024        0.1  dead_node_success

# %%
gossip_grid2d_fail = data.loc[(data['topology'] == 'grid_2d') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid2d_fail
# Out:
#      algo topology  time(microseconds)     n  Deathprob  Status
# 0  gossip  grid_2d            13554823  2025        0.1  failed
# 1  gossip  grid_2d            14040428  3025        0.1  failed

# %%
gossip_grid3d_success = data.loc[(data['topology'] == 'grid_3d') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid3d_success
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip  grid_3d             1718914    27        0.1  dead_node_success
# 1  gossip  grid_3d             1533806   125        0.1  dead_node_success
# 2  gossip  grid_3d             2211121  1000        0.1  dead_node_success
# 3  gossip  grid_3d             4897412  2197        0.1  dead_node_success
# 4  gossip  grid_3d             4083959  3375        0.1  dead_node_success

# %%
gossip_grid3d_dead = data.loc[(data['topology'] == 'grid_3d') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'dead_node_success')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid3d_dead
# Out:
#      algo topology  time(microseconds)     n  Deathprob             Status
# 0  gossip  grid_3d             1718914    27        0.1  dead_node_success
# 1  gossip  grid_3d             1533806   125        0.1  dead_node_success
# 2  gossip  grid_3d             2211121  1000        0.1  dead_node_success
# 3  gossip  grid_3d             4897412  2197        0.1  dead_node_success
# 4  gossip  grid_3d             4083959  3375        0.1  dead_node_success

# %%
gossip_grid3d_fail = data.loc[(data['topology'] == 'grid_3d') & (data['Deathprob'] == 0.1) \
                              & (data['algo'] == 'gossip') & (data['Status'] == 'failed')].reset_index(drop=True).sort_values(by=['n'])
gossip_grid3d_fail
# Out:
# Empty DataFrame
# Columns: [algo, topology, time(microseconds), n, Deathprob, Status]
# Index: []

# %%
# plot lines
plt.plot(gossip_full_success['n'], gossip_full_success['time(microseconds)']/1000, label = gossip_full_success['topology'][0])
plt.scatter(gossip_full_dead['n'], gossip_full_dead['time(microseconds)']/1000, label ='success with dead nodes', marker='o', c='g')
plt.scatter(gossip_full_fail['n'], gossip_full_fail['time(microseconds)']/1000, label ='fail with dead nodes', marker='v', c='r')

plt.plot(gossip_line_success['n'], gossip_line_success['time(microseconds)']/1000, label = gossip_line_success['topology'][0])
plt.scatter(gossip_line_dead['n'], gossip_line_dead['time(microseconds)']/1000, marker='o', c='g')
plt.scatter(gossip_line_fail['n'], gossip_line_fail['time(microseconds)']/1000, marker='v', c='r')

plt.plot(gossip_grid2d_success['n'], gossip_grid2d_success['time(microseconds)']/1000, label = gossip_grid2d_success['topology'][0])
plt.scatter(gossip_grid2d_dead['n'], gossip_grid2d_dead['time(microseconds)']/1000, marker='o', c='g')
plt.scatter(gossip_grid2d_fail['n'], gossip_grid2d_fail['time(microseconds)']/1000, marker='v', c='r')

plt.plot(gossip_grid3d_success['n'], gossip_grid3d_success['time(microseconds)']/1000, label = gossip_grid3d_success['topology'][0])
plt.scatter(gossip_grid3d_dead['n'], gossip_grid3d_dead['time(microseconds)']/1000, marker='o', c='g')
plt.scatter(gossip_grid3d_fail['n'], gossip_grid3d_fail['time(microseconds)']/1000, marker='v', c='r')
plt.legend()
plt.title("Probability of death = 0.1")
plt.xlabel("Number of Actors")
plt.ylabel("Time in milliseconds")
plt.rcParams["figure.figsize"] = (10,8)
plt.savefig('death10p')
plt.show()
